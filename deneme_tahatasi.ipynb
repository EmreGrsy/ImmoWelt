# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import math 
import logging
from tqdm import tqdm

# %%
# Configure logging to file and stdout
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[logging.FileHandler("info.log"), logging.StreamHandler()],
)

class PageURLs:
    """
    This class scraps page URLs from base_url.

    Attributes:
        base_url (str): The base URL that contains all the house listings.

    Methods:
        get_npage: Extract the maximum number of pages in base_url.
        construct_page_url: Construct individual page URLs.
        get_page_url: Get all page_urls in the base_url.
    """

    def __init__(self, base_url):
        self.base_url = base_url
        self.params = {
            "d": "true",
            "sd": "DESC",
            "sf": "RELEVANCE",
        }

    def get_npage(self):
        try:
            page = requests.get(self.base_url, timeout=10)
            page.raise_for_status()  # Raise an exception for HTTP errors
            elements = BeautifulSoup(page.content, "html.parser")
            logging.info("Base_url is opened")

            for element in elements.find_all("h1"):
                nentries = element.text.split()[0]
                logging.info(f"There are {nentries} house listings in the base_url.")

                try:
                    npage = math.ceil(int(nentries) / 20)  # Assume 20 entries per page
                except:
                    npage = math.ceil(int(nentries.replace(".", "")) / 20)  # Remove dots in large numbers
                logging.info(f"There are {npage} pages of house listings in the base_url.")

            return npage

        except requests.exceptions.RequestException as e:
            logging.error(f"Failed to open base_url: {e}")

            return 1

    def construct_page_url(self, page):
        self.params["sp"] = page
        url = (f"{self.base_url}?{'&'.join([f'{k}={v}' for k, v in self.params.items()])}")

        return url

    def get_page_urls(self):
        try:
            npage = self.get_npage()
            urls = []

            for page in range(1, npage + 1):
                url = self.construct_page_url(page)
                urls.append(url)
        except Exception as e:
            logging.error(f"An unexpected error occurred while constructing page URLS: {e}")
            return []

        return urls

class ExposeLinkExtractor:
    """
    This class scraps housing entries (expose links) from each page URL.
    """

    def __init__(self, url):
        self.url = url

    def extract_expose_links(self):

        try:
            page = requests.get(self.url, timeout=10)
            page.raise_for_status()
            elements = BeautifulSoup(page.content, "html.parser")
            flat_links = elements.find_all("a", href=True)
            expose_links = []

            for link in flat_links:
                link_href = link.get("href")
                if "/expose/" in link_href and "/projekte/expose/" not in link_href:
                    expose_links.append(link_href)

            # Sanity check
            # logging.info(f"Extracted {len(expose_links)} expose links from {self.url}")
            return expose_links

        except requests.exceptions.RequestException as e:
            logging.error(f"Error while processing the URL {self.url}: {e}")
            return []  # Return empty list

        except Exception as e:
            logging.error(f"An unexpected error occurred: {e}")
            return []

class AllURLs:
    """
    This class scrapes all house listings from the given base_url using ExposeLinkExtractor() and PageURLs().
    """
    def __init__(self, base_url):
        self.base_url = base_url

    def scrape_all_links(self):
        page_scraper = PageURLs(self.base_url)
        urls = page_scraper.get_page_urls()
        all_links = []
        
        # TODO: remove progress bar when deploying
        with tqdm(total=len(urls), desc="Scraping house listings (expose link) from each page") as pbar:
            for url in urls:
                try:
                    extractor = ExposeLinkExtractor(url)
                    expose_links = extractor.extract_expose_links()
                    if expose_links is not None:
                        all_links.extend(expose_links)
                except Exception as e:
                    logging.error(f"Failed to scrape links from {url}: {e}")
                    
                pbar.update(1)

        logging.info(f"Total links scraped: {len(all_links)}")
        return all_links

# %%
class ExposeLinkExtractor:
    """
    This class scraps housing entries (expose links) from each page URL.
    """

    def __init__(self, url):
        self.url = url

    def extract_expose_links(self):

        try:
            page = requests.get(self.url, timeout=10)
            page.raise_for_status()
            elements = BeautifulSoup(page.content, "html.parser")
            flat_links = elements.find_all("a", href=True)
            expose_links = []

            for link in flat_links:
                link_href = link.get("href")
                if "/expose/" in link_href and "/projekte/expose/" not in link_href:
                    expose_links.append(link_href)

            # Sanity check
            # logging.info(f"Extracted {len(expose_links)} expose links from {self.url}")
            return expose_links

        except requests.exceptions.RequestException as e:
            logging.error(f"Error while processing the URL {self.url}: {e}")
            return []  # Return empty list

        except Exception as e:
            logging.error(f"An unexpected error occurred: {e}")
            return []

# %%
class AllURLs:
    """
    This class scrapes all house listings from the given base_url using ExposeLinkExtractor() and PageURLs().
    """
    def __init__(self, base_url):
        self.base_url = base_url

    def scrape_all_links(self):
        page_scraper = PageURLs(self.base_url)
        urls = page_scraper.get_page_urls()
        all_links = []
        
        # TODO: remove progress bar when deploying
        with tqdm(total=len(urls), desc="Scraping house listings (expose link) from each page") as pbar:
            for url in urls:
                try:
                    extractor = ExposeLinkExtractor(url)
                    expose_links = extractor.extract_expose_links()
                    if expose_links is not None:
                        all_links.extend(expose_links)
                except Exception as e:
                    logging.error(f"Failed to scrape links from {url}: {e}")
                    
                pbar.update(1)

        logging.info(f"Total links scraped: {len(all_links)}")
        return all_links

# %%
# Define the base URL, hamburg rental units
base_url = "https://www.immowelt.de/liste/hamburg/wohnungen/mieten"

links = AllURLs(base_url)
expose_links = links.scrape_all_links()

# %%
from immowelt_urls import AllURLs
import pandas as pd
from tqdm import tqdm

base_url = "https://www.immowelt.de/liste/hamburg/wohnungen/mieten"

all_urls_scraper = AllURLs(base_url)
expose_links = all_urls_scraper.scrape_all_links()

# %%
expose_links

# %%
from immowelt_scrapper import ImmoWeltScrapper

scraper = ImmoWeltScrapper('https://www.immowelt.de/expose/2dvz55j')

row = {
    "title": scraper.get_title(),
    "address": scraper.get_address(),
    "cold_rent": scraper.get_cold_rent(),
    "warm_rent": scraper.get_warm_rent(),
    "deposit": scraper.get_deposit(),
    "living_space": scraper.get_living_space(),
    "room_number": scraper.get_room_number(),
    "floor": scraper.get_floor(),
    "availability": scraper.get_availability(),
    "amenities": scraper.get_amenities(),
    "built_year": scraper.get_built_year(),
    "energy_consumption": scraper.get_energy_consumption(),
    "object_detail": scraper.get_detail_object(),
    "furnishing": scraper.get_detail_furnishing(),
    "extra": scraper.get_detail_extra(),
    "timestamp": scraper.get_query_time()
}

# %%
json_object = json.loads(data)

if "props" in json_object:
    if "pageProps" in json_object["props"]:
        if "classified" in json_object["props"]["pageProps"]:
            if "sections" in json_object["props"]["pageProps"]["classified"]:
                if "similarListings" in json_object["props"]["pageProps"]["classified"]["sections"]:
                    json_object["props"]["pageProps"]["classified"]["sections"].pop("similarListings")
            if "seo" in json_object["props"]["pageProps"]["classified"]:
                json_object["props"]["pageProps"]["classified"].pop("seo")
            if "advertising" in json_object["props"]["pageProps"]["classified"]:
                json_object["props"]["pageProps"]["classified"].pop("advertising")
            if "tracking" in json_object["props"]["pageProps"]["classified"]:
                json_object["props"]["pageProps"]["classified"].pop("tracking")
            if "contactSections" in json_object["props"]["pageProps"]["classified"]:
                json_object["props"]["pageProps"]["classified"].pop("contactSections")
        if "i18nResources" in json_object["props"]["pageProps"]:
            json_object["props"]["pageProps"].pop("i18nResources")
        if "headerFooterConfig" in json_object["props"]["pageProps"]:
            json_object["props"]["pageProps"].pop("headerFooterConfig")
if "page" in json_object:
     json_object.pop("page")
if "query" in json_object:
     json_object.pop("query")
if "buildId" in json_object:
     json_object.pop("buildId")
if "assetPrefix" in json_object:
     json_object.pop("assetPrefix")
if "isFallback" in json_object:
     json_object.pop("isFallback")
if "gssp" in json_object:
     json_object.pop("gssp")
if "scriptLoader" in json_object:
     json_object.pop("scriptLoader")

json_formatted_str = json.dumps(json_object, indent=4)
print(json_formatted_str)

# %%
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime
import pandas as pd
import json


url = 'https://www.immowelt.de/expose/2dvz55j'

page = requests.get(url)
elements = BeautifulSoup(page.content, "html.parser")
data = elements.find('script', id='__NEXT_DATA__').text

json_object = json.loads(data)

json_formatted_str = json.dumps(json_object, indent=4)
print(json_formatted_str)

# %%
data = {}

id = json_object["props"]["pageProps"]["classified"]["id"]
title = json_object["props"]["pageProps"]["classified"]["title"]

creationDate = c
updateDate = json_object["props"]["pageProps"]["classified"]["metadata"]["updateDate"]

city = json_object["props"]["pageProps"]["classified"]["sections"]["location"]["address"]["city"]
zipCode = json_object["props"]["pageProps"]["classified"]["sections"]["location"]["address"]["zipCode"]
street = json_object["props"]["pageProps"]["classified"]["sections"]["location"]["address"]["street"]
district = json_object["props"]["pageProps"]["classified"]["sections"]["location"]["address"]["district"]

coordinates = json_object["props"]["pageProps"]["classified"]["sections"]["location"]["geometry"]["coordinates"]

# No need for description, yet, there is too much text to parse in an meaningful way. 

facts_dict = {}
facts = json_object["props"]["pageProps"]["classified"]["sections"]["hardFacts"]["facts"]

for fact in facts:
    print(fact["type"], fact["value"])
    facts_dict[fact["type"]] = fact["value"]
    
locationDescription = json_object["props"]["pageProps"]["classified"]["sections"]["hardFacts"]["locationDescription"]

features_dict = {}
features = json_object["props"]["pageProps"]["classified"]["sections"]["energy"]["features"]
for feature in features:
    features_dict[feature["type"]] = feature["value"]

certificates_dict = {}
certificates = json_object["props"]["pageProps"]["classified"]["sections"]["energy"]["certificates"][0]["features"] # It is a list
for feature in certificates:
    certificates_dict[feature["type"]] = feature["value"]

energyRating_dict = {}
energyRating = json_object["props"]["pageProps"]["classified"]["sections"]["energy"]["certificates"][0]["scales"][0]["efficiencyClass"]["rating"]
energyRequirement = json_object["props"]["pageProps"]["classified"]["sections"]["energy"]["certificates"][0]["scales"][0]["values"][0]["value"]

energyRating_dict = {"energyRating": energyRating, "energyRequirement": energyRequirement}

housePrices_dict = {}
housePrices = json_object["props"]["pageProps"]["classified"]["sections"]["price"]["base"]["details"]
for housePrice in housePrices:
    housePrices_dict[housePrice["label"]["main"]] = housePrice["value"]["main"]["value"]

# No need for additional price elements, e.g. monthly parking rent or caution. This has nothing to do with the house quality, hence isn't necessary in the model.

details_dict = {}
details = json_object["props"]["pageProps"]["classified"]["sections"]["features"]["details"]["categories"]
for detail in details:
    for element in detail["elements"]:
        details_dict[element["icon"]] = element["value"]

# %%
data = {
    "id": id,
    "title": title,
    "creationDate": creationDate,
    "updateDate": updateDate,
    "city": city,
    "zipCode": zipCode,
    "street": street,
    "district": district,
    "coordinates": coordinates,
    "locationDescription": locationDescription
}
data.update(facts_dict)
data.update(features_dict)
data.update(certificates_dict)
data.update(energyRating_dict)
data.update(housePrices_dict)
data.update(details_dict)

# %%
data

# %%
details_dict = {}
details = json_object["props"]["pageProps"]["classified"]["sections"]["features"]["details"]["categories"]
for detail in details:
    for element in detail["elements"]:
        details_dict[element["icon"]] = element["value"]

# %%
print(priceAdditionals["label"])

# %%
# description atlatdik cunku cok text var

#facts_dict = {}
#facts = json_object["props"]["pageProps"]["classified"]["sections"]["hardFacts"]["facts"]
#for fact in facts:
#    value = re.sub(r'[^\d.,]', '', fact["value"]).replace(',', '.')
#    if value:
#        facts_dict[fact["type"]] = float(value)

# %%
import requests
from bs4 import BeautifulSoup
import logging


# Configure logging to file and stdout
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[logging.FileHandler("info.log"), logging.StreamHandler()],
)

class ParsePageJson:
    """
    Extracts housing related data from the JSON object obtained from the webpage.

    Attributes:
        page_url (str): The URL of the webpage containing the JSON object.
        page_json (dict): The JSON object to parse.
        num_total_features (int): The total number of features to extract.
        num_extracted_features (int): The number of features successfully extracted.
        data (dict): The extracted data.

    Methods:
        __init__(page_url): Initializes the object with the page URL and loads the JSON object.
        get_json_object(): Loads the JSON object from the webpage.
        extract_features(): Extracts the housing related data from the JSON object.
    """

    def __init__(self, page_url):
        self.page_url = page_url
        self.num_total_features = 12
        self.num_extracted_features = 0
        self.data = {}
        self.get_json_object()


    def get_json_object(self):
        page = requests.get(self.page_url, timeout=10)
        page.raise_for_status()  # Raise an exception for HTTP errors
        elements = BeautifulSoup(page.content, "html.parser")
        data = elements.find('script', id='__NEXT_DATA__').text
        self.page_json = json.loads(data)


    def extract_features(self):

        try:
            self.data["id"] = self.page_json["props"]["pageProps"]["classified"]["id"]
            self.num_extracted_features += 1
        except Exception as e:
            self.data["id"] = None

        try:
            self.data["title"] = self.page_json["props"]["pageProps"]["classified"]["title"]
            self.num_extracted_features += 1
        except Exception as e:
            self.data["title"] = None

        try:
            self.data["creationDate"] = self.page_json["props"]["pageProps"]["classified"]["metadata"]["creationDate"]
            self.num_extracted_features += 1
        except Exception as e:
            self.data["creationDate"] = None

        try:
            self.data["updateDate"] = self.page_json["props"]["pageProps"]["classified"]["metadata"]["updateDate"]
            self.num_extracted_features += 1
        except Exception as e:
            self.data["updateDate"] = None

        try:
            self.data["city"] = self.page_json["props"]["pageProps"]["classified"]["sections"]["location"]["address"]["city"]
            self.num_extracted_features += 1
        except Exception as e:
            self.data["city"] = None

        try:
            self.data["zipCode"] = self.page_json["props"]["pageProps"]["classified"]["sections"]["location"]["address"]["zipCode"]
            self.num_extracted_features += 1
        except Exception as e:
            self.data["zipCode"] = None

        try:
            self.data["street"] = self.page_json["props"]["pageProps"]["classified"]["sections"]["location"]["address"]["street"]
            self.num_extracted_features += 1
        except Exception as e:
            self.data["street"] = None

        try:
            self.data["district"] = self.page_json["props"]["pageProps"]["classified"]["sections"]["location"]["address"]["district"]
            self.num_extracted_features += 1
        except Exception as e:
            self.data["district"] = None

        try:
            self.data["coordinates"] = self.page_json["props"]["pageProps"]["classified"]["sections"]["location"]["geometry"]["coordinates"]
            self.num_extracted_features += 1
        except Exception as e:
            self.data["coordinates"] = None

        try:
            self.data["locationDescription"] = self.page_json["props"]["pageProps"]["classified"]["sections"]["hardFacts"]["locationDescription"]
            self.num_extracted_features += 1
        except Exception as e:
            self.data["locationDescription"] = None            

        try:
            facts_dict = {}
            facts = self.page_json["props"]["pageProps"]["classified"]["sections"]["hardFacts"]["facts"]
            for fact in facts:
                facts_dict[fact["type"]] = fact["value"]
            self.data.update(facts_dict)
            self.num_extracted_features += 1
        except Exception as e:
            pass

        try:
            features_dict = {}
            features = self.page_json["props"]["pageProps"]["classified"]["sections"]["energy"]["features"]
            for feature in features:
                features_dict[feature["type"]] = feature["value"]
            self.data.update(features_dict)
            self.num_extracted_features += 1
        except Exception as e:
            pass

        try:
            certificates_dict = {}
            certificates = self.page_json["props"]["pageProps"]["classified"]["sections"]["energy"]["certificates"][0]["features"]
            for feature in certificates:
                certificates_dict[feature["type"]] = feature["value"]
            self.data.update(certificates_dict)
            self.num_extracted_features += 1
        except Exception as e:
            pass

        try:
            energyRating_dict = {}
            energyRating = self.page_json["props"]["pageProps"]["classified"]["sections"]["energy"]["certificates"][0]["scales"][0]["efficiencyClass"]["rating"]
            energyRequirement = self.page_json["props"]["pageProps"]["classified"]["sections"]["energy"]["certificates"][0]["scales"][0]["values"][0]["value"]
            energyRating_dict = {"energyRating": energyRating, "energyRequirement": energyRequirement}
            self.data.update(energyRating_dict)
            self.num_extracted_features += 1
        except Exception as e:
            pass

        try:
            housePrices_dict = {}
            housePrices = self.page_json["props"]["pageProps"]["classified"]["sections"]["price"]["base"]["details"]
            for housePrice in housePrices:
                housePrices_dict[housePrice["label"]["main"]] = housePrice["value"]["main"]["value"]
            self.data.update(housePrices_dict)
            self.num_extracted_features += 1
        except Exception as e:
            pass

        try:
            details_dict = {}
            details = self.page_json["props"]["pageProps"]["classified"]["sections"]["features"]["details"]["categories"]
            for detail in details:
                for element in detail["elements"]:
                    details_dict[element["icon"]] = element["value"]
            self.data.update(details_dict)
            self.num_extracted_features += 1
        except Exception as e:
            pass
		
        logging.info(f"Total number of features extracted from {self.page_url}: {self.num_extracted_features}/16")

        return self.data

# %%
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime
import pandas as pd
import json


url = 'https://www.immowelt.de/expose/2fc3d5w'

pg = ParsePageJson(url)

data = pg.extract_features()

# %%
data

# %%
    try:
        features_dict = {}
        features = json_object["props"]["pageProps"]["classified"]["sections"]["energy"]["features"]
        for feature in features:
            features_dict[feature["type"]] = feature["value"]
        data.update("features_dict")
        if data["features_dict"]
        successful_extractions += 1
    except Exception as e:
        data["features"] = {}


    try:
        certificates_dict = {}
        certificates = json_object["props"]["pageProps"]["classified"]["sections"]["energy"]["certificates"][0]["features"]
        for feature in certificates:
            certificates_dict[feature["type"]] = feature["value"]
        data["certificates"] = certificates_dict
        successful_extractions += 1
    except Exception as e:
        data["certificates"] = {}


    try:
        energyRating_dict = {}
        energyRating = json_object["props"]["pageProps"]["classified"]["sections"]["energy"]["certificates"][0]["scales"][0]["efficiencyClass"]["rating"]
        energyRequirement = json_object["props"]["pageProps"]["classified"]["sections"]["energy"]["certificates"][0]["scales"][0]["values"][0]["value"]
        energyRating_dict = {"energyRating": energyRating, "energyRequirement": energyRequirement}
        data["energyRating"] = energyRating_dict
        successful_extractions += 1
    except Exception as e:
        data["energyRating"] = {}
    successful_extractions += 1

    try:
        housePrices_dict = {}
        housePrices = json_object["props"]["pageProps"]["classified"]["sections"]["price"]["base"]["details"]
        for housePrice in housePrices:
            housePrices_dict[housePrice["label"]["main"]] = housePrice["value"]["main"]["value"]
        data["housePrices"] = housePrices_dict
        successful_extractions += 1

# %%
from immowelt_urls import AllURLs
from immowelt_parse import ParsePageJson


base_url = "https://www.immowelt.de/liste/hamburg/wohnungen/mieten"

all_urls_scraper = AllURLs(base_url)
expose_links = all_urls_scraper.scrape_all_links()

data = {}

for expose_link in expose_links:
    page_data = {}
    page = ParsePageJson(expose_link)
    page_data = page.extract_features()
    data.update(page_data)

# %%
from immowelt_urls import AllURLs
from immowelt_parse import ParsePageJson
from concurrent.futures import ThreadPoolExecutor
import requests
from bs4 import BeautifulSoup
import logging
import json


# Configure logging to file and stdout
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14426/3378399767.py in <module>
#      25
#      26 for link in expose_links:
# ---> 27     page = ParsePageJson(link)
#      28     page_data = page.extract_features()
#      29     data.append(page_data)
#
# ~/Desktop/scrapper/ImmoWelt/immowelt_parse.py in __init__(self, page_url)
#      35         self.data = {}
#      36         self.valid_json = True
# ---> 37         self.get_json_object()
#      38
#      39
#
# ~/Desktop/scrapper/ImmoWelt/immowelt_parse.py in get_json_object(self)
#      40     def get_json_object(self):
#      41         page = requests.get(self.page_url, timeout=30)
# ---> 42         elements = BeautifulSoup(page.content, "html.parser")
#      43         data = elements.find('script', id='__NEXT_DATA__').text
#      44         logging.info(f"{self.page_url}")
#
# ~/anaconda3/lib/python3.9/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     360             self.reset()
#     361             try:
# --> 362                 self._feed()
#     363                 success = True
#     364                 break
#
# ~/anaconda3/lib/python3.9/site-packages/bs4/__init__.py in _feed(self)
#     446         self.builder.reset()
#     447
# --> 448         self.builder.feed(self.markup)
#     449         # Close out any unfinished strings and close all the open tags.
#     450         self.endData()
#
# ~/anaconda3/lib/python3.9/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     390         parser.soup = self.soup
#     391         try:
# --> 392             parser.feed(markup)
#     393             parser.close()
#     394         except HTMLParseError as e:
#
# ~/anaconda3/lib/python3.9/html/parser.py in feed(self, data)
#     108         """
#     109         self.rawdata = self.rawdata + data
# --> 110         self.goahead(0)
#     111
#     112     def close(self):
#
# ~/anaconda3/lib/python3.9/html/parser.py in goahead(self, end)
#     172                     k = self.parse_endtag(i)
#     173                 elif startswith("<!--", i):
# --> 174                     k = self.parse_comment(i)
#     175                 elif startswith("<?", i):
#     176                     k = self.parse_pi(i)
#
# ~/anaconda3/lib/python3.9/_markupbase.py in parse_comment(self, i, report)
#     175         if report:
#     176             j = match.start(0)
# --> 177             self.handle_comment(rawdata[i+4: j])
#     178         return match.end(0)
#     179
#
# ~/anaconda3/lib/python3.9/site-packages/bs4/builder/_htmlparser.py in handle_comment(self, data)
#     256         self.soup.endData()
#     257         self.soup.handle_data(data)
# --> 258         self.soup.endData(Comment)
#     259
#     260     def handle_decl(self, data):
#
# ~/anaconda3/lib/python3.9/site-packages/bs4/__init__.py in endData(self, containerClass)
#     585             containerClass = self.string_container(containerClass)
#     586             o = containerClass(current_data)
# --> 587             self.object_was_parsed(o)
#     588
#     589     def object_was_parsed(self, o, parent=None, most_recent_element=None):
#
# KeyboardInterrupt:

# %%
data
# Out:
# [{'id': '24TRNCT4U8W1',
#   'url': 'https://www.immowelt.de/expose/55db9a19-9a5e-464f-9a13-9a26dc3fb427',
#   'title': '2 Zi.-Whg., 62 qm, DBad, Einbauküche, großer Balkon. Soeben saniert, zahlreiche Geräte/Einrichtungen neu (Dusche, Waschmaschine, Herd, Kühlschrank, Lampen, Fussboden, Rollos).  Möbliert. TV/WLAN incl.. Fahrstuhl, Schwimmbad, Sauna im Gebäude. Tiefgaragenplatz ab Sommer 2025 möglich.<br>Uneinsehbare Endetage mit fantastischem Blick ins Alstertal. Ungestört sonnen, grillen, die Natur genießen. Binnen 1-3 Minuten im Alstertal spazieren oder Fahrrad fahren.<br>Für 1-2 Personen.<br><br>Objektzustand: Erstbezug nach Sanierung',
#   'creationDate': '2024-10-08T08:36:03.353Z',
#   'updateDate': '2024-10-08T08:54:16.687Z',
#   'city': 'Hamburg',
#   'zipCode': '22399',
#   'street': None,
#   'district': 'Poppenbüttel',
#   'coordinates': None,
#   'locationDescription': 'Alsterkehre (Poppenbüttel). Kein Verkehrslärm. Gute Busanbindung zu AEZ u. S-Bahn Poppenbüttel bzw. U-Bahn Borgweg. Direkt neben Alsterwanderweg. Fußläufig zu Geschäften, Ärzten, Apotheken, Kirchen, etc.<br>Infrastruktur (im Umkreis von 5 km):<br>Apotheke, Lebensmittel-Discount, Allgemeinmediziner, Öffentliche Verkehrsmittel',
#   'numberOfRooms': '2 Zimmer',
#   'livingSpace': '62 m²<br/>Wohnfläche',
#   'numberOfFloors': '4.<br/>Geschoss',
#   'Description': '2 Zi.-Whg., 62 qm, DBad, Einbauküche, großer Balkon. Soeben saniert, zahlreiche Geräte/Einrichtungen neu (Dusche, Waschmaschine, Herd, Kühlschrank, Lampen, Fussboden, Rollos).  Möbliert. TV/WLAN incl.. Fahrstuhl, Schwimmbad, Sauna im Gebäude. Tiefgaragenplatz ab Sommer 2025 möglich.<br>Uneinsehbare Endetage mit fantastischem Blick ins Alstertal. Ungestört sonnen, grillen, die Natur genießen. Binnen 1-3 Minuten im Alstertal spazieren oder Fahrrad fahren.<br>Für 1-2 Personen.<br><br>Objektzustand: Erstbezug nach Sanierung',
#   'Lage': 'Alsterkehre (Poppenbüttel). Kein Verkehrslärm. Gute Busanbindung zu AEZ u. S-Bahn Poppenbüttel bzw. U-Bahn Borgweg. Direkt neben Alsterwanderweg. Fußläufig zu Geschäften, Ärzten, Apotheken, Kirchen, etc.<br>Infrastruktur (im Umkreis von 5 km):<br>Apotheke, Lebensmittel-Discount, Allgemeinmediziner, Öffentliche Verkehrsmittel',
#   'Weitere Informationen': 'Sonstiges\nHeizungsart: Zentralheizung<br>Energieträger: Öl<br>Energieausweis nicht vorhanden<br><br>ohne Courtage direkt vom Eigentümer. NK ca. € 300 mtl. (bei 1-Pers.-Haushalt). Staffelmiete +4% p.a.. Mietvertrag befristet auf 3-4 Jahre wegen Eigenbedarfs.<br><br>Makleranfragen nicht erwünscht. Nach § 7 UWG sind unaufgeforderte Kontaktaufnahmen durch Makler ohne ausdrückliche Einwilligung des Empfängers verboten!\n\nStichworte\nNutzfläche: 82,00 m², Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, Anzahl Balkone: 2, Bundesland: Hamburg, 4 Etagen',
#   'yearOfConstruction': '1970',
#   'state': 'renoviert / saniert',
#   'heatingSystem': 'Zentralheizung',
#   'energySource': 'Öl',
#   'availability': 'nach Absprache',
#   'floors': '4. Geschoss',
#   'elevator': 'Personenaufzug',
#   'cellar': 'Kelleranteil',
#   'bathroom-amenities': 'Bad mit Dusche',
#   'kitchen': 'Einbauküche',
#   'floor-covering': 'Bodenbelag: Fliesen, Laminat',
#   'balcony': 'Balkon',
#   'parking-lots': '1 Stellplatz',
#   'swimming-pool': 'Swimmingpool'},
#  {'id': '24NG4US2GB4S',
#   'url': 'https://www.immowelt.de/expose/757ce35b-1d58-42f4-8db7-6835cf4fa7ed',
#   'title': 'Dieses Homelike-Apartment können Sie direkt auf unserer Plattform anfragen.<br>        Klicken Sie dazu bitte auf den folgenden Link: [URL="https://www.thehomelike.com/apartment/63dd47601448f17255d1?lang=de&utm_source=immowelt&utm_medium=listing&utm_campaign=immowelt_de&om_src=immowelt&om_medium=listing&om_cmpgn=Hamburg&om_trg=de"] Apartment auf thehomelike.com[/URL] (Sie werden zum Anbieter weitergeleitet).<br>        Auf Homelike finden Sie weitere Details, können das Apartment bequem online anfragen, buchen und den Mietvertrag online unterschreiben!<br>        <br>        HAM-904978<br><br>Willkommen in dieser zeitgemäßen Wohnung mit zwei Zimmern und einer  Wohnfläche von 51 m², idyllisch gelegen im Hamburger Stadtteil Horn, 350 m von der U-Bahnstation Horner Rennbahn entfernt. In Gehweite zu Lebensmittelgeschäften, Schulen, Kita.Kurzfristige Miete ist zwischen 3 und 12 Monaten möglich.Das Apartment teilt sich in folgende Räume auf- Flur- Küche-Studio- Bad- Schlafzimmer- GartenEichenparkettboden mit Fußbodenheizung, geöltStudio:Einbauküche4 Platten KochfeldBackofenMikrowelleKaffeemaschineKühlschrank Waschmaschine TV  55 Zoll  TV-Bank4-er SchlaffSofa1 BarTisch mit 3 StühlenNotwendiger Geschirr und BesteckSchlafzimmer:Bett 1,80 x 2,00 Meter2m Schrank1 Kommode2 NachttischeSpiegel Flur:SchuhschrankSchuhbankHutablageSchtaubsaugerBadezimmer:Duschkabine Spiegelschrank RegalNebenkosten sind inklusiveWLANStrom Wasser usw.Inventar:gesamtes Inventar incl.BügeleisenBügelbrettWäscheständerGeschirrBesteckKüchenzubehörBettwäsche HandtücherKostenlose offene Parkplätze entlang der Straße, keine Reservierung möglich.Da die Wohnung neu ist, beachten Sie bitte, dass der Eingang noch renoviert wird.Hinweis: Die angezeigten Preise und Daten sind nicht unbedingt final und sollten nur zu Informationszwecken verwendet werden. Sie sind nicht Vertragsgegenstand und demnach nicht verbindlich. Energieausweis Dieses Gebäude unterliegt nicht den Anforderungen der EnEV.',
#   'creationDate': '2024-10-07T13:46:49.563Z',
#   'updateDate': '2024-10-09T12:12:33.394Z',
#   'city': 'Hamburg',
#   'zipCode': '22111',
#   'street': 'Washingtonallee',
#   'district': 'Horn',
#   'coordinates': None,
#   'locationDescription': 'idyllisch gelegen im Hamburger Stadtteil Horn, 350 m von der U-Bahnstation Horner Rennbahn entfernt. In Gehweite zu Lebensmittelgeschäften, Schulen, Kita.Kostenlose offene Parkplätze entlang der Straße, keine Reservierung möglich.Da die Wohnung neu ist, beachten Sie bitte, dass der Eingang noch renoviert wird.',
#   'numberOfRooms': '3 Zimmer',
#   'livingSpace': '51 m²<br/>Wohnfläche',
#   'availability': 'frei ab sofort',
#   'Description': 'Dieses Homelike-Apartment können Sie direkt auf unserer Plattform anfragen.<br>        Klicken Sie dazu bitte auf den folgenden Link: [URL="https://www.thehomelike.com/apartment/63dd47601448f17255d1?lang=de&amp;utm_source=immowelt&amp;utm_medium=listing&amp;utm_campaign=immowelt_de&amp;om_src=immowelt&amp;om_medium=listing&amp;om_cmpgn=Hamburg&amp;om_trg=de"] Apartment auf thehomelike.com[/URL] (Sie werden zum Anbieter weitergeleitet).<br>        Auf Homelike finden Sie weitere Details, können das Apartment bequem online anfragen, buchen und den Mietvertrag online unterschreiben!<br>        <br>        HAM-904978<br><br>Willkommen in dieser zeitgemäßen Wohnung mit zwei Zimmern und einer  Wohnfläche von 51 m², idyllisch gelegen im Hamburger Stadtteil Horn, 350 m von der U-Bahnstation Horner Rennbahn entfernt. In Gehweite zu Lebensmittelgeschäften, Schulen, Kita.Kurzfristige Miete ist zwischen 3 und 12 Monaten möglich.Das Apartment teilt sich in folgende Räume auf- Flur- Küche-Studio- Bad- Schlafzimmer- GartenEichenparkettboden mit Fußbodenheizung, geöltStudio:Einbauküche4 Platten KochfeldBackofenMikrowelleKaffeemaschineKühlschrank Waschmaschine TV  55 Zoll  TV-Bank4-er SchlaffSofa1 BarTisch mit 3 StühlenNotwendiger Geschirr und BesteckSchlafzimmer:Bett 1,80 x 2,00 Meter2m Schrank1 Kommode2 NachttischeSpiegel Flur:SchuhschrankSchuhbankHutablageSchtaubsaugerBadezimmer:Duschkabine Spiegelschrank RegalNebenkosten sind inklusiveWLANStrom Wasser usw.Inventar:gesamtes Inventar incl.BügeleisenBügelbrettWäscheständerGeschirrBesteckKüchenzubehörBettwäsche HandtücherKostenlose offene Parkplätze entlang der Straße, keine Reservierung möglich.Da die Wohnung neu ist, beachten Sie bitte, dass der Eingang noch renoviert wird.Hinweis: Die angezeigten Preise und Daten sind nicht unbedingt final und sollten nur zu Informationszwecken verwendet werden. Sie sind nicht Vertragsgegenstand und demnach nicht verbindlich. Energieausweis Dieses Gebäude unterliegt nicht den Anforderungen der EnEV.',
#   'Lage': 'idyllisch gelegen im Hamburger Stadtteil Horn, 350 m von der U-Bahnstation Horner Rennbahn entfernt. In Gehweite zu Lebensmittelgeschäften, Schulen, Kita.Kostenlose offene Parkplätze entlang der Straße, keine Reservierung möglich.Da die Wohnung neu ist, beachten Sie bitte, dass der Eingang noch renoviert wird.',
#   'Weitere Informationen': 'Sonstiges\nHomelike Code: HAM-904978\n\nStichworte\nGesamtfläche: 51,00 m², Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, nur Nichtraucher',
#   'max-persons': 'max. 3 Personen',
#   'floors': 'Erdgeschoss',
#   'furnished': 'möbliert',
#   'bathroom-amenities': 'Bad mit Dusche',
#   'kitchen': 'Einbauküche, offene Küche'},
#  {'id': '24ZW369MT7Q6',
#   'url': 'https://www.immowelt.de/expose/8801cdc4-27a3-4a2e-aaba-2e3f76874505',
#   'primaryEnergySource': 'Fernwärme',
#   'energyRating': 'B',
#   'energyRequirement': '60,8 kWh/(m²·a)',
#   'Nebenkosten': '405\xa0€',
#   'Heizkosten': 'in Warmmiete enthalten',
#   'Warmmiete': '2.100\xa0€',
#   'availability': 'ab sofort',
#   'floors': '3. Geschoss',
#   'elevator': 'Personenaufzug',
#   'kitchen': 'Einbauküche',
#   'balcony': 'Balkon',
#   'terrace': 'Terrasse',
#   'parking-lots': '1 Stellplatz'},
#  {'id': '23XUQG1R8SXG',
#   'url': 'https://www.immowelt.de/expose/de49c7b7-d654-4af6-b972-1494c9f3edec',
#   'title': 'Dieses Homelike-Apartment können Sie direkt auf unserer Plattform anfragen.<br>        Klicken Sie dazu bitte auf den folgenden Link: [URL="https://www.thehomelike.com/apartment/e27a123121ffbab6eb9d?lang=de&utm_source=immowelt&utm_medium=listing&utm_campaign=immowelt_de&om_src=immowelt&om_medium=listing&om_cmpgn=Hamburg&om_trg=de"] Apartment auf thehomelike.com[/URL] (Sie werden zum Anbieter weitergeleitet).<br>        Auf Homelike finden Sie weitere Details, können das Apartment bequem online anfragen, buchen und den Mietvertrag online unterschreiben!<br>        <br>        HAM-770484<br><br>Hochwertiges Design, beeindruckender Komfort und eine Prise Behaglichkeit sind für uns die Zutaten für modernes und entspanntes Wohnen.Jobnomaden und Pendler finden in unseren Apartments nach getaner Arbeit all die schönen und nützlichen Dinge, die einen heimischen und inspirierenden Aufenthalt möglich machen. Genießen Sie Ihre Unabhängigkeit in der vollausgestatteten Küche, freuen Sie sich auf ihre Lieblingssendung auf dem 40 Zoll LED-Fernseher oder surfen Sie auf dem kuscheligen Sofa kostenfrei mit WLAN im Internet.Ein obligatorischer Wäschewechsel mit Reinigungsservice ist zwei mal im Monat mit inbegriffen.Hinweis: Die angezeigten Preise und Daten sind nicht unbedingt final und sollten nur zu Informationszwecken verwendet werden. Sie sind nicht Vertragsgegenstand und demnach nicht verbindlich. Energieausweis Ausweis Typ:  :  Baujahr: 1960 Effizienzklasse: C Verbrauch: 90kWh / (m²a)',
#   'creationDate': '2024-10-02T10:24:57.117Z',
#   'updateDate': '2024-10-03T22:03:33.861Z',
#   'city': 'Hamburg',
#   'zipCode': '21073',
#   'street': 'Ruststraße',
#   'district': 'Eißendorf',
#   'coordinates': None,
#   'locationDescription': 'In einer ruhigen Seitenstraße gelegen, aber trotzdem mitten im Leben, werden Sie den Lifestyle Hamburgs spüren und erreichen alle wichtigen Einkaufsmöglichkeiten bequem zu Fuß. Zur Erholung in Hamburgs Natur warten in unmittelbarer Nähe die Harburger Berge auf Sie.Harburg liegt an der Südelbe und  ist perfekt um der Großstadt Hamburg zu entfliehen und im Harburger Stadtpark den Kopf frei zu bekommen.',
#   'numberOfRooms': '2 Zimmer',
#   'livingSpace': '54 m²<br/>Wohnfläche',
#   'availability': 'frei ab 01.04.2025',
ehören ein 32" Smart-TV und eine Bluetooth-Box.  In der offenen Küche (integriert im Wohnbereich) gibt es einen Induktionsherd (4 Kochfelder) mit Backofen und Dunstabzug, eine Kühl-Gefrierkombination, eine Spülmaschine und einen Esstisch. Nutzliche Kleingeräte sowie Essgeschirr, Geschirrtücher und Kochgeschirr werden gestellt. Es gibt zwei Schlafzimmer. In das größere Schlafzimmer mit Doppelbett (160 x 200 cm), Erker und Zugang zum Balkon gelangt man durch einen vorgelagerten Ankleidebereich. Im kleineren Schlafzimmer befindet sich ein Schreibtisch und ein Stapelbett (90x200), welches sich zu einem Doppelbett (180x200) vergrößern lässt. Bad mit, Badewanne mit Duschmöglichkeit, Handtuchheizung, Waschbecken und großes Fenster. Eine separate Toilette ist vorhanden. Bettwäsche und Handtücher sind nach Absprache möglich. Die Waschmaschine befindet sich im Badezimmer.<br>Die möblierte Wohnung ist für maximal 3 Personen geeignet.  Eine Wohngemeinschaft ist für maximal 2 Personen erlaubt. Ein kleiner Hund ist nach Absprache erlaubt (Haftpflichtversicherung erforderlich), eine Katze ist nicht erlaubt. Folgende Kosten sind in der Miete enthalten: Strom-Pauschale inkl., Wasser-Pauschale inkl., Heizung-Pauschale inkl.. Rundfunkgebühren inkl. Ein Internetanschluss (DSL/WLAN / 100 Mbit) kann genutzt werden.<br>Verbrauchsausweis',
#   'creationDate': '2024-09-23T18:18:06.21Z',
#   'updateDate': '2024-09-24T22:02:25.394Z',
#   'city': 'Hamburg',
#   'zipCode': '22527',
#   'street': 'Jaguarstieg',
#   'district': 'Stellingen',
#   'coordinates': None,
#   'locationDescription': '1. Etage',
#   'numberOfRooms': '3 Zimmer',
#   'livingSpace': '99 m²<br/>Wohnfläche',
#   'availability': '01.11.2024<br/>Verfügbarkeit',
#   'Description': 'Modern ausgestattete Wohnung in einer ruhigen Seitenstraße mit altem Baumbestand mitten in Hamburg-Eimsbüttel. Die 3-Zimmer-Wohnung mit Haus-im-Haus-Charakter wurde 2007 gebaut und im Dezember 2022 neu ausgestattet. Sie liegt in der 1. Etage eines kleinen Mehrfamilienhauses und hat zwei Balkone. Insgesamt ist die ca. 99 qm große Wohnung sehr hell, wird mit einer Zentralheizung beheizt und hat zu jeder Jahreszeit ein angenehmes Raumklima. Hinter dem Haus gibt es einen Gemeinschaftsgarten. Im Hinterhof stehen zwei abschließbare Fahrradstellplätze zur Verfügung.<br>Im gesamten Wohnbereich ist Stäbchenparkett verlegt. Das Wohnzimmer ist komplett möbliert. Zur technischen Ausstattung gehören ein 32" Smart-TV und eine Bluetooth-Box.  In der offenen Küche (integriert im Wohnbereich) gibt es einen Induktionsherd (4 Kochfelder) mit Backofen und Dunstabzug, eine Kühl-Gefrierkombination, eine Spülmaschine und einen Esstisch. Nutzliche Kleingeräte sowie Essgeschirr, Geschirrtücher und Kochgeschirr werden gestellt. Es gibt zwei Schlafzimmer. In das größere Schlafzimmer mit Doppelbett (160 x 200 cm), Erker und Zugang zum Balkon gelangt man durch einen vorgelagerten Ankleidebereich. Im kleineren Schlafzimmer befindet sich ein Schreibtisch und ein Stapelbett (90x200), welches sich zu einem Doppelbett (180x200) vergrößern lässt. Bad mit, Badewanne mit Duschmöglichkeit, Handtuchheizung, Waschbecken und großes Fenster. Eine separate Toilette ist vorhanden. Bettwäsche und Handtücher sind nach Absprache möglich. Die Waschmaschine befindet sich im Badezimmer.<br>Die möblierte Wohnung ist für maximal 3 Personen geeignet.  Eine Wohngemeinschaft ist für maximal 2 Personen erlaubt. Ein kleiner Hund ist nach Absprache erlaubt (Haftpflichtversicherung erforderlich), eine Katze ist nicht erlaubt. Folgende Kosten sind in der Miete enthalten: Strom-Pauschale inkl., Wasser-Pauschale inkl., Heizung-Pauschale inkl.. Rundfunkgebühren inkl. Ein Internetanschluss (DSL/WLAN / 100 Mbit) kann genutzt werden.<br>Verbrauchsausweis',
#   'Lage': '1. Etage',
#   'Weitere Informationen': 'Stichworte\nAnzahl Balkone: 1, nur Nichtraucher, Mindestmietdauer: 3 Monate',
#   'yearOfConstruction': '2007',
#   'basedOn': 'Verbrauchsausweis',
#   'validity': 'ab 08.12.2020',
#   'primaryEnergySource': 'Erdgas schwer'},
#  {'id': '24GKHU1PTBQP',
#   'url': 'https://www.immowelt.de/expose/b40c2f95-e6b0-4ffe-8cf6-42ce2e5abe37',
#   'title': 'Objektreferenz: VM-LN2967<br><br>Die hier angebotene 3-Zimmer-Wohnung befindet sich in einem gepflegten Mehrfamilienhaus, welches im Jahre 1981 in massiver Bauweise errichtet wurde.<br><br>Die Außenfassade präsentiert sich in einem klassischen Rotklinker. Dazu passend korrespondieren die weißen Kunststofffenster.<br><br>Die Beheizung sowie die Warmwasserversorgung erfolgen über eine Gaszentralheizung aus dem Jahre 2004. <br><br>Für genügend Stellfläche sorgt ein Kellerraum. Dieser steht dem Mieter zur alleinigen Nutzung zur Verfügung.<br><br><br>Diese Wohnung eignet sich hervorragend für einen Personenkreis, der die ruhige Umgebung trotz der zentralen Lage in Bergedorf und die gute städtische Anbindung zu schätzen weiß.',
#   'creationDate': '2024-09-23T13:50:39.043Z',
#   'updateDate': '2024-09-30T19:11:15.773Z',
#   'city': 'Hamburg',
#   'zipCode': '21035',
#   'street': None,
#   'district': 'Bergedorf',
#   'coordinates': None,
#   'locationDescription': 'Bergedorf ist ein Stadtteil von Hamburg mit über 36.000 Einwohnern und verfügt über eine sehr gute Infrastruktur mit attraktiven Shoppingmöglichkeiten, zahlreichen Restaurants, einem eigenen Theater sowie einer denkmalgeschützten Sternwarte, einem Krankenhaus und dem einzigen Schloss Hamburgs. In der Innenstadt gibt es sehenswerte Fachwerkhäuser wie das Gasthaus Stadt Hamburg von 1550 zu entdecken, in dem seit über 40 Jahren ein "Block House" mit leckeren Steaks und weiteren Speisen zu finden ist. <br>Sämtliche Schulformen und Kindergärten sind fußläufig bzw. mit dem Fahrrad erreichbar. Abwechslungsreiche Sport- und Freizeitmöglichkeiten bieten der TSG Bergedorf, die nahegelegenen Golf-, Tennis- und Hockeyclubs, zahlreiche Reitanlagen in der Umgebung, das Bergedorfer Gehölz sowie das Bille-Bad. <br>In ca. 20 Minuten erreicht man sowohl mit der S-Bahn als auch mit dem PKW bequem die Hamburger Innenstadt. Ebenfalls verkehrsgünstig gelegen sind die Anschlussstellen an die A1 (Lübeck-Bremen) sowie A24 (Hamburg-Berlin).',
#   'numberOfRooms': '3 Zimmer',
#   'livingSpace': '84,5 m²<br/>Wohnfläche',
#   'numberOfFloors': '2.<br/>Geschoss',
#   'availability': 'frei ab 01.11.2024',
#   'Description': 'Objektreferenz: VM-LN2967<br><br>Die hier angebotene 3-Zimmer-Wohnung befindet sich in einem gepflegten Mehrfamilienhaus, welches im Jahre 1981 in massiver Bauweise errichtet wurde.<br><br>Die Außenfassade präsentiert sich in einem klassischen Rotklinker. Dazu passend korrespondieren die weißen Kunststofffenster.<br><br>Die Beheizung sowie die Warmwasserversorgung erfolgen über eine Gaszentralheizung aus dem Jahre 2004. <br><br>Für genügend Stellfläche sorgt ein Kellerraum. Dieser steht dem Mieter zur alleinigen Nutzung zur Verfügung.<br><br><br>Diese Wohnung eignet sich hervorragend für einen Personenkreis, der die ruhige Umgebung trotz der zentralen Lage in Bergedorf und die gute städtische Anbindung zu schätzen weiß.',
#   'Lage': 'Bergedorf ist ein Stadtteil von Hamburg mit über 36.000 Einwohnern und verfügt über eine sehr gute Infrastruktur mit attraktiven Shoppingmöglichkeiten, zahlreichen Restaurants, einem eigenen Theater sowie einer denkmalgeschützten Sternwarte, einem Krankenhaus und dem einzigen Schloss Hamburgs. In der Innenstadt gibt es sehenswerte Fachwerkhäuser wie das Gasthaus Stadt Hamburg von 1550 zu entdecken, in dem seit über 40 Jahren ein "Block House" mit leckeren Steaks und weiteren Speisen zu finden ist. <br>Sämtliche Schulformen und Kindergärten sind fußläufig bzw. mit dem Fahrrad erreichbar. Abwechslungsreiche Sport- und Freizeitmöglichkeiten bieten der TSG Bergedorf, die nahegelegenen Golf-, Tennis- und Hockeyclubs, zahlreiche Reitanlagen in der Umgebung, das Bergedorfer Gehölz sowie das Bille-Bad. <br>In ca. 20 Minuten erreicht man sowohl mit der S-Bahn als auch mit dem PKW bequem die Hamburger Innenstadt. Ebenfalls verkehrsgünstig gelegen sind die Anschlussstellen an die A1 (Lübeck-Bremen) sowie A24 (Hamburg-Berlin).',
#   'Weitere Informationen': 'Sonstiges\nHINWEIS ZUR BEWERBUNG:<br>Um Ihnen den bestmöglichen Service zu bieten, können Sie sich bei uns digital bewerben. Kopieren Sie den untenstehenden Link in die Adresszeile Ihres Browsers und folgen Sie der Anleitung. <br><br> https://rdr.immomio.com/WO2QzzWr<br><br>[URL="https://rdr.immomio.com/WO2QzzWr"]Interessentenlink[/URL]\n\nStichworte\nAnzahl der Schlafzimmer: 2, Anzahl der Badezimmer: 2, Anzahl Balkone: 1, Bundesland: Hamburg',
#   'yearOfConstruction': '1981',
#   'state': 'gepflegt',
#   'energySource': 'Gas',
#   'basedOn': 'Verbrauchsausweis',
#   'yearOfConstructionBuilding': '2004',
#   'primaryEnergySource': 'Gas',
#   'energyRating': 'F',
#   'energyRequirement': '162,5 kWh/(m²·a)',
#   'Nebenkosten': '300\xa0€',
#   'Heizkosten': 'in Warmmiete enthalten',
#   'floors': '2. Geschoss',
#   'cellar': 'Kelleranteil',
#   'bathroom-amenities': 'Badewanne, Bad mit Fenster',
#   'toilet-amenities': 'Gäste-WC',
#   'kitchen': 'Einbauküche',
#   'floor-covering': 'Bodenbelag: Teppich',
#   'balcony': 'Balkon',
#   'tv': 'Kabelanschluss'},
#  {'id': '244LQJHA5667',
#   'url': 'https://www.immowelt.de/expose/809315e4-3b16-4e03-932f-3539f80c934a',
#   'title': 'In direkter Nähe zum Lise-Meitner-Park entstand im Jahre 1998 ein Ensemble von vier Neubauten mit einer gemeinsamen Tiefgarage. Die Architektur dieser besonderen Häuser lebt von einem Wechselspiel der Formen, die klare Linienführung wird bewusst durch das prägnant farblich abgesetzte Tonnendach sowie dem ebenfalls akzentuierten Treppenhaus- und Eingangsbereich optisch aufgelockert.<br><br>Diese Endetagenwohnung mit drei Dachterrassen, einer Galerieebene und direktem Zugang über einen Fahrstuhl, bietet einen außergewöhnlichen Grundriss. Das Wohn- und Esszimmer ist geprägt von der Deckenhöhe und der Öffnung zur Galerieebene. Die großen Fensterflächen ermöglichen zu jeder Tageszeit eine besonders gute Belichtung und viele spannende Blickbeziehungen. <br><br>Die Galerieebene ist über eine geschwungene Treppe aus dem Wohnbereich zu erreichen und bietet Platz für ein Arbeits- oder Gästezimmer. Von hier aus beeindruckt der fantastische Blick über die Dächer der Nachbarschaft bis in die Hamburger Innenstadt. Vom Wohnbereich ist einerseits der Blick auf eine Südterrasse, und der Zugang zur großen Süd- Westterrasse gegeben.<br><br>Die Küche ist durch ein Glaselement vom Wohnbereich separiert und mit einer modernen Einbauküche ausgestattet. Die Küche verfügt über ein Glasdach mit Sonnenschutz und ist durch die umlaufenden Fester ebenfalls sehr gut belichtet. Auch von hier ist der Zugang zur Terrasse gegeben.<br><br>Das Hauptschlafzimmer verfügt über ein Bad en suite sowie über einen Zugang zur östlichen Dachterrasse. Dem zweiten Schlaf-, Arbeits- oder Kinderzimmer ist ebenfalls weiteres Badezimmer sowie ein praktischer Einbauschrank zugeordnet. Von hieraus ist die Dachterrasse in südlicher Ausrichtung zu erreichen. <br><br>Im Bereich des Treppenaufganges befindet sich zudem ausreichend Platz für eine Garderobe. <br><br>Zur Wohnung können zwei Tiefgaragenstellplätze à mtl. EUR 85,- angemietet werden.<br><br>Ein großer Kellerraum (7,5 m²) ist dieser Wohnung zugehörig.',
#   'creationDate': '2024-09-23T12:11:30.793Z',
#   'updateDate': '2024-10-08T11:42:34.119Z',
#   'city': 'Hamburg',
#   'zipCode': '22607',
#   'street': None,
#   'district': 'Bahrenfeld',
#   'coordinates': None,
#   'Weitere Informationen': 'Homepage\nhttp://www.meissler-co.de\n\nMietvertrag\nunbefristet, Mindestlaufzeit, Indexmiete\n\nSonstiges\nDie Wasser- und Stromkosten zahlt der Mieter direkt an die Versorgungsträger.\n\nStellplatz/Stellp...\nZwei TG-Stellplätze können angemietet werden (mtl. à EUR 85,-).',
#   'yearOfConstruction': '1998',
#   'state': 'gepflegt',
#   'energySource': 'Gas',
#   'basedOn': 'Bedarfsausweis',
#   'yearOfConstructionBuilding': '1998',
#   'primaryEnergySource': 'Gas',
#   'energyRating': 'D',
#   'energyRequirement': '115 kWh/(m²·a)',
#   'Nebenkosten': '475\xa0€',
#   'Heizkosten': 'in Warmmiete enthalten',
#   'Warmmiete': '3.090\xa0€',
#   'floors': '2. Geschoss',
#   'elevator': 'Personenaufzug',
#   'cellar': 'Kelleranteil',
#   'bathroom-amenities': 'Badewanne, Bad mit Dusche, Bad mit Fenster',
#   'kitchen': 'Einbauküche',
#   'floor-covering': 'Bodenbelag: Parkett',
#   'balcony': 'Balkon',
#   'terrace': 'Terrasse',
#   'parking-lots': '2 Stellplätze'},
#  {'id': '24MTUU26UG5J',
#   'url': 'https://www.immowelt.de/expose/624b0a5b-7239-4cf0-8b53-3d4f44978b82',
#   'title': 'Dieses Homelike-Apartment können Sie direkt auf unserer Plattform anfragen.<br>        Klicken Sie dazu bitte auf den folgenden Link: [URL="https://www.thehomelike.com/apartment/139a7f060b509107a523?lang=de&utm_source=immowelt&utm_medium=listing&utm_campaign=immowelt_de&om_src=immowelt&om_medium=listing&om_cmpgn=Hamburg&om_trg=de"] Apartment auf thehomelike.com[/URL] (Sie werden zum Anbieter weitergeleitet).<br>        Auf Homelike finden Sie weitere Details, können das Apartment bequem online anfragen, buchen und den Mietvertrag online unterschreiben!<br>        <br>        HAM-604441<br><br>Unsere Wohnungen erfüllen alle Ihre täglichen Lebensbedürfnisse. Jede Wohnung ist mit einer Küche inklusive Kühlschrank, Kochutensilien und Geschirr ausgestattet. Die Wohnungen verfügen außerdem über eine Waschmaschine und WLAN-Internet. Jedes Zimmer ist voll möbliert und bietet ein bequemes Bett mit frischer Bettwäsche und einen Arbeitsbereich. - Die demografische Gruppe, die diese Immobilie bucht, besteht hauptsächlich aus Studenten und jungen Berufstätigen. - Bitte beachten Sie, dass Einzugsvereinbarungen an Wochenenden oder Feiertagen nicht möglich sind. Daher wird der Check-in auf den nächsten verfügbaren Werktag verschoben. Diese Änderung hat keine Auswirkungen auf den Preis oder die Mietdauer. - Die Endreinigungsgebühr beinhaltet nicht nur die Endreinigung selbst, sondern stellt auch eine Mitgliedsgebühr dar, die dem Mieter Zugang zu einer internationalen Community junger Berufstätiger gewährt. Sie genießen verschiedene Angebote von handverlesenen lokalen Unternehmen und andere Vergünstigungen. - Nach der Buchung wird direkt mit dem Vermieter ein unbefristeter Mietvertrag abgeschlossen. Ohne aktive Kündigung verlängert sich der Mietvertrag automatischHinweis: Die angezeigten Preise und Daten sind nicht unbedingt final und sollten nur zu Informationszwecken verwendet werden. Sie sind nicht Vertragsgegenstand und demnach nicht verbindlich. Energieausweis Dieses Gebäude unterliegt nicht den Anforderungen der EnEV.',
#   'creationDate': '2024-09-20T11:36:30.227Z',
#   'updateDate': '2024-10-05T22:03:12.373Z',
#   'city': 'Hamburg',
#   'zipCode': '21079',
#   'street': 'Schellerdamm 7a',
#   'district': 'Harburg',
#   'coordinates': None,
#   'locationDescription': 'Das Viertel bietet Ihnen zahlreiche Einkaufsmöglichkeiten und eine hervorragende Anbindung an den öffentlichen Nahverkehr.',
#   'numberOfRooms': '4 Zimmer',
#   'livingSpace': '15,5 m²<br/>Wohnfläche',
#   'availability': 'frei ab 06.01.2025',
#   'Description': 'Dieses Homelike-Apartment können Sie direkt auf unserer Plattform anfragen.<br>        Klicken Sie dazu bitte auf den folgenden Link: [URL="https://www.thehomelike.com/apartment/139a7f060b509107a523?lang=de&amp;utm_source=immowelt&amp;utm_medium=listing&amp;utm_campaign=immowelt_de&amp;om_src=immowelt&amp;om_medium=listing&amp;om_cmpgn=Hamburg&amp;om_trg=de"] Apartment auf thehomelike.com[/URL] (Sie werden zum Anbieter weitergeleitet).<br>        Auf Homelike finden Sie weitere Details, können das Apartment bequem online anfragen, buchen und den Mietvertrag online unterschreiben!<br>        <br>        HAM-604441<br><br>Unsere Wohnungen erfüllen alle Ihre täglichen Lebensbedürfnisse. Jede Wohnung ist mit einer Küche inklusive Kühlschrank, Kochutensilien und Geschirr ausgestattet. Die Wohnungen verfügen außerdem über eine Waschmaschine und WLAN-Internet. Jedes Zimmer ist voll möbliert und bietet ein bequemes Bett mit frischer Bettwäsche und einen Arbeitsbereich. - Die demografische Gruppe, die diese Immobilie bucht, besteht hauptsächlich aus Studenten und jungen Berufstätigen. - Bitte beachten Sie, dass Einzugsvereinbarungen an Wochenenden oder Feiertagen nicht möglich sind. Daher wird der Check-in auf den nächsten verfügbaren Werktag verschoben. Diese Änderung hat keine Auswirkungen auf den Preis oder die Mietdauer. - Die Endreinigungsgebühr beinhaltet nicht nur die Endreinigung selbst, sondern stellt auch eine Mitgliedsgebühr dar, die dem Mieter Zugang zu einer internationalen Community junger Berufstätiger gewährt. Sie genießen verschiedene Angebote von handverlesenen lokalen Unternehmen und andere Vergünstigungen. - Nach der Buchung wird direkt mit dem Vermieter ein unbefristeter Mietvertrag abgeschlossen. Ohne aktive Kündigung verlängert sich der Mietvertrag automatischHinweis: Die angezeigten Preise und Daten sind nicht unbedingt final und sollten nur zu Informationszwecken verwendet werden. Sie sind nicht Vertragsgegenstand und demnach nicht verbindlich. Energieausweis Dieses Gebäude unterliegt nicht den Anforderungen der EnEV.',
#   'Lage': 'Das Viertel bietet Ihnen zahlreiche Einkaufsmöglichkeiten und eine hervorragende Anbindung an den öffentlichen Nahverkehr.',
#   'Weitere Informationen': 'Sonstiges\nHomelike Code: HAM-604441\n\nStichworte\nGesamtfläche: 15,50 m², Anzahl der Schlafzimmer: 4, Anzahl der Badezimmer: 1, nur Nichtraucher',
#   'flat-share-possible': 'WG-geeignet',
#   'max-persons': 'max. 1 Person',
#   'floors': '4. Geschoss',
#   'furnished': 'möbliert',
#   'bathroom-amenities': 'Bad mit Dusche',
#   'kitchen': 'Einbauküche, Kochnische'},
#  {'id': '23HGSR5T6BLK',
#   'url': 'https://www.immowelt.de/expose/e83d7371-1af0-4c49-a68c-5f98bfb1e3e5',
#   'title': 'Diese herausragende Penthouse-Wohnung mit umlaufender Dachterrasse liegt in ruhiger Hinterhoflage mitten in Hamburg-Eimsbüttel. Von dem eignen Parkplatz sind es nur wenige Schritte zum Aufzug, der direkt in die 4. Etage fährt. Das in 2020 fertig gestellte und ausgestattete Penthouse befindet sich auf dem Dach eines 2019/2020 grundsanierten Gewerbe-Altbaus von 1905. Auf der rundum verlaufenden Terrasse gibt es einen Sitzbereich nach Südosten. <br>Durch die bodentiefen Fenster ist die Wohnung sehr hell (alle Fenster mit Sonnenschutz-Jalousien von außen). Im Wohnbereich wurde hochwertiger Vinylboden in Holzoptik verlegt. <br>Das großzügige Wohnzimmer teilt sich auf in einen Wohnbereich mit Ledersofa, Sessel und Flat-TV (48", Kabel) sowie einen Essbereich mit einem Esstisch für sechs Personen. Zu der Ausstattung gehören hochwertige Designmöbeln von z.B. Thonet, 2C und Tisch sowie ein wunderschöner antiker Apothekerschrank. <br>Die zum Wohnzimmer offene Küche ist komplett ausgestattet. Weitere Arbeitsfläche zum Kochen bietet eine praktische Insel mit einer Arbeitsplatte aus Holz, die nicht auf den Fotos zu sehen ist. <br>Insgesamt gibt es drei Schlafzimmer in der Wohnung. Im Hauptschlafzimmer gibt es ein Doppelbett (180x200) sowie einen weiteren Flat TV (nicht auf den Fotos zu sehen). In den anderen beiden Schlafzimmern befinden sich gute Futon-Schlafsofas (120x200). Bei Bedarf kann eines der beiden Schlafzimmer auch als Arbeitszimmer genutzt werden, ein großer Schreibtisch ist vorhanden.<br>Im Badezimmer mit Fenster gibt es eine Badewanne und eine bodentiefe Dusche mit Glaskabine. Separate Gästetoilette. Die Waschmaschine steht in der Abstellkammer. Fahrradabstellplatz im Haus.<br>In der Miete enthalten sind die Nebenkosten als Pauschale und die Rundfunkgebühr. Eine WLAN-Flat (250MBit) und eine Telefonflatrate ins deutsche Festnetz stehen zur Verfügung und können genutzt werden. In der Miete sind 7% MwSt. enthalten.<br>Niedrigenergiehaus (Energieausweis nicht erforderlich)',
#   'creationDate': '2024-09-11T15:18:05.687Z',
#   'updateDate': '2024-10-02T18:18:05.672Z',
#   'city': 'Hamburg',
#   'zipCode': '20255',
#   'street': 'Lutterothstraße',
#   'district': 'Stellingen',
#   'coordinates': None,
#   'locationDescription': '4. Etage',
#   'numberOfRooms': '4 Zimmer',
#   'livingSpace': '159 m²<br/>Wohnfläche',
#   'availability': 'ab sofort<br/>Verfügbarkeit',
#   'Description': 'Diese herausragende Penthouse-Wohnung mit umlaufender Dachterrasse liegt in ruhiger Hinterhoflage mitten in Hamburg-Eimsbüttel. Von dem eignen Parkplatz sind es nur wenige Schritte zum Aufzug, der direkt in die 4. Etage fährt. Das in 2020 fertig gestellte und ausgestattete Penthouse befindet sich auf dem Dach eines 2019/2020 grundsanierten Gewerbe-Altbaus von 1905. Auf der rundum verlaufenden Terrasse gibt es einen Sitzbereich nach Südosten. <br>Durch die bodentiefen Fenster ist die Wohnung sehr hell (alle Fenster mit Sonnenschutz-Jalousien von außen). Im Wohnbereich wurde hochwertiger Vinylboden in Holzoptik verlegt. <br>Das großzügige Wohnzimmer teilt sich auf in einen Wohnbereich mit Ledersofa, Sessel und Flat-TV (48", Kabel) sowie einen Essbereich mit einem Esstisch für sechs Personen. Zu der Ausstattung gehören hochwertige Designmöbeln von z.B. Thonet, 2C und Tisch sowie ein wunderschöner antiker Apothekerschrank. <br>Die zum Wohnzimmer offene Küche ist komplett ausgestattet. Weitere Arbeitsfläche zum Kochen bietet eine praktische Insel mit einer Arbeitsplatte aus Holz, die nicht auf den Fotos zu sehen ist. <br>Insgesamt gibt es drei Schlafzimmer in der Wohnung. Im Hauptschlafzimmer gibt es ein Doppelbett (180x200) sowie einen weiteren Flat TV (nicht auf den Fotos zu sehen). In den anderen beiden Schlafzimmern befinden sich gute Futon-Schlafsofas (120x200). Bei Bedarf kann eines der beiden Schlafzimmer auch als Arbeitszimmer genutzt werden, ein großer Schreibtisch ist vorhanden.<br>Im Badezimmer mit Fenster gibt es eine Badewanne und eine bodentiefe Dusche mit Glaskabine. Separate Gästetoilette. Die Waschmaschine steht in der Abstellkammer. Fahrradabstellplatz im Haus.<br>In der Miete enthalten sind die Nebenkosten als Pauschale und die Rundfunkgebühr. Eine WLAN-Flat (250MBit) und eine Telefonflatrate ins deutsche Festnetz stehen zur Verfügung und können genutzt werden. In der Miete sind 7% MwSt. enthalten.<br>Niedrigenergiehaus (Energieausweis nicht erforderlich)',
#   'Lage': '4. Etage',
#   'Weitere Informationen': 'Stichworte\nAnzahl Balkone: 1, nur Nichtraucher, Mindestmietdauer: 3 Monate',
#   'yearOfConstruction': '2020'},
#  {'id': '23M3IS2645SA',
#   'url': 'https://www.immowelt.de/expose/ef910e90-5ec0-43fc-a5f4-6df6f9cd6304',
# ...
#   'creationDate': '2024-10-10T15:17:54.413Z',
#   'updateDate': '2024-10-10T15:18:12.947Z',
#   'city': 'Hamburg',
#   'zipCode': '21029',
#   'street': 'Holtenklinker Straße',
#   'district': 'Bergedorf',
#   'coordinates': None,
#   'locationDescription': 'Erdgeschoss',
#   'numberOfRooms': '3 Zimmer',
#   'livingSpace': '86 m²<br/>Wohnfläche',
#   'availability': '01.11.2024<br/>Verfügbarkeit',
#   'Description': 'Komplett möblierte 3-Zimmer-Wohnung mit Süd-Balkon in Hamburg-Bergedorf in der Nähe des Bergedorfer Schlossparks. Die ca. 86 qm große, individuelle und hochwertig eingerichtete Wohnung befindet sich im Erdgeschoss einer 2016 sanierten Stadtvilla. Weitere Besonderheiten der Wohnung sind die Wandgestaltung, die hohen Stuckdecken und die original geschliffenen Pitchpine-Dielen. Das Objekt wird mit einer Zentralheizung, Fußbodenheizung und einem  dampfbetriebenen Kamin beheizt. Ein PKW-Stellplatz steht im Innenhof zur Verfügung und kann bei Bedarf angemietet werden (Kosten zzgl.).<br>Es gibt einen großen Wohn-Essbereich, bestehend aus zwei miteinander verbundene Zimmer. Das Wohnzimmer ist mit einem Schlafsofa (für Gäste, Liegefläche 140 x 200 cm), Kamin, 46" Smart-TV und Hi-Fi-Anlage ausgestattet. Der Esstisch bietet Platz zum Essen, Gästeempfang oder Arbeiten. Die ca. 11 qm große Küche verfügt über eine Einbauzeile mit Ceranherd  (4 Kochfelder), Backofen, Dunstabzug, Mikrowelle in Sichthöhe, Spülmaschine und Kühl-Gefrierkombination. Das geräumige Schlafzimmer ist mit einem großen Doppelbett (180x200), einem Sofa und einem Arbeitsplatz mit einem iMac ausgestattet. Folgende Wäsche wird gestellt: Bettdecken, Bettwäsche, Handtücher und Kissen. Das ca. 10 qm große Bad ist mit Badewanne, separater bodengleicher Dusche mit Regendusche, Tageslicht, Handtuchheizung und WC ausgestattet. Es gibt eine praktische Abstellkammer und die Waschmaschine befindet sich im eigenen Kellerabteil.<br>Die möblierte Wohnung ist für maximal 3 Personen geeignet. Eine Wohngemeinschaft ist für maximal 2 Personen erlaubt. Ein Hund oder eine Katze sind nicht erlaubt. Die Miete beinhaltet bereits folgende Kosten: Heizung-Pauschale, Wasser-Pauschale, Strom-Pauschale. Der Rundfunkbeitrag ist inklusive. Ein Internetanschluss (WLAN / 50 Mbit) kann genutzt werden. <br>Der Energieausweis liegt uns momentan nicht vor (ist angefordert)',
#   'Lage': 'Erdgeschoss',
#   'Weitere Informationen': 'Stichworte\nAnzahl Balkone: 1, nur Nichtraucher, Mindestmietdauer: 3 Monate'},
#  {'id': '24XMQ9VHHF3R',
#   'url': 'https://www.immowelt.de/expose/f3779ac4-d581-4155-beb7-edd17ab1b8d0',
#   'title': 'Objektreferenz: 14487<br><br>Das gepflegte Mehrfamilienhaus wurde 2022 errichtet.<br>Die Wohnanlage befindet sich in einem sehr guten Zustand.<br><br>Die angebotene Wohnung befindet sich im vierten Obergeschoss und verfügt über ca. 44 m² Wohnfläche, welche sich auf ein Wohnzimmer mit Küchenzeile, ein halbes Zimmer, das Badezimmer sowie einen beheizten Wintergarten verteilt.',
#   'creationDate': '2024-10-10T15:09:48.587Z',
#   'updateDate': '2024-10-10T15:09:54.296Z',
#   'city': 'Hamburg / Hammerbrook',
#   'zipCode': '20097',
#   'street': 'Recha-Lübke-Damm 3',
#   'district': 'Hammerbrook',
#   'coordinates': None,
#   'locationDescription': 'Der Stadteil St. Georg ist sehr zentral, multikulturell und voller Leben. Die nahgelegende Straße "Lange Reihe" ist eine abwechslungsreiche Einkaufsmeile mit vielen Cafe`s, Kneipen und originellen Läden.<br><br>Die öffentlichen Verkehrsmittel sind mit Busstationen und dem Bahnhof "Berliner Tor" optimal gegeben.',
#   'numberOfRooms': '1,5 Zimmer',
#   'livingSpace': '44,5 m²<br/>Wohnfläche',
#   'numberOfFloors': '4.<br/>Geschoss',
#   'availability': 'frei ab 01.11.2024',
#   'Description': 'Objektreferenz: 14487<br><br>Das gepflegte Mehrfamilienhaus wurde 2022 errichtet.<br>Die Wohnanlage befindet sich in einem sehr guten Zustand.<br><br>Die angebotene Wohnung befindet sich im vierten Obergeschoss und verfügt über ca. 44 m² Wohnfläche, welche sich auf ein Wohnzimmer mit Küchenzeile, ein halbes Zimmer, das Badezimmer sowie einen beheizten Wintergarten verteilt.',
#   'Lage': 'Der Stadteil St. Georg ist sehr zentral, multikulturell und voller Leben. Die nahgelegende Straße "Lange Reihe" ist eine abwechslungsreiche Einkaufsmeile mit vielen Cafe`s, Kneipen und originellen Läden.<br><br>Die öffentlichen Verkehrsmittel sind mit Busstationen und dem Bahnhof "Berliner Tor" optimal gegeben.',
#   'Weitere Informationen': 'Sonstiges\nEs wird ein Indexmietvertrag mit einem Kündigungsausschluss von 12 Monaten vereinbart.<br><br>Strom und Wasserkosten sind separat bei den jeweiligen Versorgern anzumelden.<br><br>Die Kosten für die Treppenhausreinigung sind in der Miete enthalten. <br><br> HINWEIS ZUR BEWERBUNG:<br>Um Ihnen den bestmöglichen Service zu bieten, können Sie sich bei uns digital bewerben. Kopieren Sie den untenstehenden Link in die Adresszeile Ihres Browsers und folgen Sie der Anleitung. <br><br> https://rdr.immomio.com/tc6XcN<br><br>[URL="https://rdr.immomio.com/tc6XcN"]Interessentenlink[/URL]\n\nStichworte\nFahrradraum, Anzahl der Schlafzimmer: 1, Anzahl der Badezimmer: 1, Anzahl Loggias: 1, Bundesland: Hamburg',
#   'yearOfConstruction': '2022',
#   'state': 'gepflegt',
#   'energySource': 'Fernwärme',
#   'basedOn': 'Bedarfsausweis',
#   'yearOfConstructionBuilding': '2022',
#   'primaryEnergySource': 'Keine Angaben',
#   'Nebenkosten': '90\xa0€',
#   'Heizkosten': '60\xa0€',
#   'floors': '4. Geschoss',
#   'elevator': 'Personenaufzug',
#   'cellar': 'Kelleranteil',
#   'bathroom-amenities': 'Bad mit Dusche',
#   'kitchen': 'Einbauküche',
#   'floor-covering': 'Bodenbelag: Parkett',
#   'loggia': 'Loggia'},
#  {'id': '24X419CZ7ZQZ',
#   'url': 'https://www.immowelt.de/expose/5b2e52f1-1cb3-4d9a-9b7f-1c787d26b53e',
#   'title': 'Dieses Objekt besteht aus 2 ganzen und 2 halben Zimmern.<br>Objektreferenz: MO 2000/6272/32',
#   'creationDate': '2024-10-10T15:03:56.723Z',
#   'updateDate': '2024-10-10T15:04:08.152Z',
#   'city': 'Hamburg',
#   'zipCode': '22045',
#   'street': 'Lichtenberger Str. 1a',
#   'district': 'Jenfeld',
#   'coordinates': None,
Teich. Mittendrin befindet sich das "Haus am See" an der Schöneberger Straße als Treffpunkt für Jung und Alt: Das Angebot reicht vom Café über Kurse bis hin zur Beratung. Natürlich sind Kindertagesstätten und Schulen ebenfalls vor Ort. Die täglichen Besorgungen können bequem zu Fuß erledigt werden. Darüber hinaus sorgen verschiedene Buslinien für eine gute Verbindung in die Innenstadt und die benachbarten Stadtteile."',
#   'Weitere Informationen': 'Sonstiges\nBei Interesse fragen Sie das Objekt bitte online an und registrieren sich im Anschluss bei Immomio.<br><br>Die Wohnung ist an eine Familie mit 4 Personen zu vermieten. Ein passender § 5 Schein ist von Vorteil! <br><br> HINWEIS ZUR BEWERBUNG:<br>Um Ihnen den bestmöglichen Service zu bieten, können Sie sich bei uns digital bewerben. Kopieren Sie den untenstehenden Link in die Adresszeile Ihres Browsers und folgen Sie der Anleitung. <br><br> https://rdr.immomio.com/pfHki<br><br>[URL="https://rdr.immomio.com/pfHki"]Interessentenlink[/URL]\n\nStichworte\nAnzahl Balkone: 1, Bundesland: Hamburg',
#   'yearOfConstruction': '1997',
#   'energySource': 'Kohle, Fernwärme',
#   'basedOn': 'Verbrauchsausweis',
#   'yearOfConstructionBuilding': '1997',
#   'primaryEnergySource': 'Kohle',
#   'energyRating': 'C',
#   'energyRequirement': '89,8 kWh/(m²·a)',
#   'Nebenkosten': '150,86\xa0€',
#   'Heizkosten': '90,87\xa0€',
#   'floors': '3. Geschoss',
#   'cellar': 'Kelleranteil',
#   'bathroom-amenities': 'Badewanne',
#   'balcony': 'Balkon'},
#  {'id': '24UIWRWEVEQI',
#   'url': 'https://www.immowelt.de/expose/71695a4e-5f3c-48d6-a64b-2bdabd6710bc',
#   'title': 'Objektreferenz: MO 2000/6035/67',
#   'creationDate': '2024-10-10T15:03:47.863Z',
#   'updateDate': '2024-10-10T15:04:04.638Z',
#   'city': 'Hamburg',
#   'zipCode': '22045',
#   'street': 'Spandauer Weg 11',
#   'district': 'Jenfeld',
#   'coordinates': None,
#   'locationDescription': '"Zwischen Wandsbek und Rahlstedt<br><br>Hohenhorster sind echte Grenzgänger! Denn mitten durch Hohenhorst, in Höhe des Einkaufszentrumsam Berliner Platz, verläuft die Stadtteilgrenze zwischen Wandsbek und Rahlstedt. Im Stadtbild ist davon allerdings nichts zu sehen.Im Gegenteil: Hohenhorst<br>präsentiert sich als harmonischer, in sich geschlossener und dabei trotzdem abwechslungsreicher Stadtteil. Das fängt bei der Bebauung an - vom Hochhaus mit tollem<br>Rundumblick bis zum Reihenhaus mit eigenem Garten ist alles vorhanden.<br><br>Wo die Natur ruft<br><br>Wer keinen eigenen Garten hat, findet genug Natur gleich vor der Haustür; beginnend beim kleinen Park mit See am Berliner Platz über die Wiesen und Kleingärten entlang des Schleemer Bachs bis hin zur weitläufigen Feldmark im Osten von Hohenhorst. Hier gilt es übrigens gleich die nächste Grenze zu überschreiten, denn Schleswig-Holstein ist ganz nah und lockt mit Wiesen, Feldern und ländlichen Ortschaften.<br><br>Wo die Kinder spielen<br><br>Neben den zahlreich
#   'yearOfConstruction': '1960',
#   'energySource': 'Fernwärme',
#   'basedOn': 'Verbrauchsausweis',
#   'yearOfConstructionBuilding': '1960',
#   'primaryEnergySource': 'Fernwärme',
#   'energyRating': 'E',
#   'energyRequirement': '135,2 kWh/(m²·a)',
#   'Nebenkosten': '91,71\xa0€',
#   'Heizkosten': '57,09\xa0€',
#   'floors': '3. Geschoss',
#   'elevator': 'Personenaufzug',
#   'cellar': 'Kelleranteil',
#   'bathroom-amenities': 'Bad mit Dusche',
#   'balcony': 'Balkon'}]

# %%
from immowelt_urls import PageURLs
from immowelt_urls import ExposeLinkExtractor
from immowelt_urls import AllURLs

base_url = "https://www.immowelt.de/liste/hamburg/wohnungen/mieten"

page_scraper = PageURLs(base_url)
urls = page_scraper.get_page_urls()

# %%
urls[0]

extractor = ExposeLinkExtractor(urls[0])
expose_links = extractor.extract_expose_links()

# %%
expose_links

# %%
all_urls_scraper = AllURLs(base_url)
expose_links = all_urls_scraper.scrape_all_links(urls[0])

# %%
expose_links

# %% [markdown]
# Add details, and save a template.

# %%
url = expose_links[18]

page = requests.get(url)
elements = BeautifulSoup(page.content, "html.parser")
data = elements.find('script', id='__NEXT_DATA__').text

json_object = json.loads(data)

json_formatted_str = json.dumps(json_object, indent=4)
print(json_formatted_str)

expose_links[18]

# %%
url = expose_links[1]

page = requests.get(url)
elements = BeautifulSoup(page.content, "html.parser")
data = elements.find('script', id='__NEXT_DATA__').text

json_object = json.loads(data)

json_formatted_str = json.dumps(json_object, indent=4)
print(json_formatted_str)

expose_links[1]

# %%
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime
import pandas as pd
import json


url = 'https://www.immowelt.de/expose/2dvz55j'

page = requests.get(url)
elements = BeautifulSoup(page.content, "html.parser")
data = elements.find('script', id='__NEXT_DATA__').text

json_object = json.loads(data)

json_formatted_str = json.dumps(json_object, indent=4)
print(json_formatted_str)


kk = json_object["props"]["pageProps"]["classified"]["metadata"]["status"]["status"]

# %%
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime
import pandas as pd
import json


url = 'https://www.immowelt.de/expose/2dvz55j'

page = requests.get(url)
elements = BeautifulSoup(page.content, "html.parser")
data = elements.find('script', id='__NEXT_DATA__').text

json_object = json.loads(data)


data = {}

textDetails_dict = {}
num_extracted_features = 0
textDetails = json_object["props"]["pageProps"]["classified"]["sections"]["description"]["texts"]
for textDetail in textDetails:
    if "headline" in textDetail:
        headline = textDetail["headline"]
    else:
        headline = "Description"
    text = textDetail["text"]
    textDetails_dict[headline] = text
    num_extracted_features += 1

data.update(textDetails_dict)

# %% [markdown]
# https://www.immowelt.de/classified-search?distributionTypes=Rent&estateTypes=Apartment&locations=AD08DE1113&page=2
# https://www.immowelt.de/classified-search?distributionTypes=Buy,Buy_Auction,Compulsory_Auction&estateTypes=House&locations=AD08DE7633&page=3

# %%
data

# %%
addressPublished = json_object["props"]["pageProps"]["classified"]["sections"]["location"]["isAddressPublished"]
if addressPublished is True:

coordinates = json_object["props"]["pageProps"]["classified"]["sections"]["location"]["geometry"]["coordinates"]
